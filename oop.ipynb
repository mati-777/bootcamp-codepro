# %%
# no completado, no funciona el codigo :(
class Animales:
    Especie = 'Ave'

    def _init_(self, nombre, color):
        self.nombre = nombre
        self.color = color 

pitogue = Animales("Federico','Negro")    
print (f'soy {pitogue} y soy de color {pitogue}')

# %%
# no terminado 
class Mascota :
    tipo = 'Domestico'

    def __init__(self,color ,raza ):
        self.color = color 
        self.raza = raza

    def saludar (self):
        print('hola humano, buenos dias')   

    def mover_cola (self):
        print('estoy muy feliz, mira como muevo la cola ')

class Perro (mascota):
    jugueton = 100

    def

# %%
# no completado, lo mas probable es que no cumpla con los requisitos estipulados por el challenge 
class Heroe:
    def __init__(self,nombre1):
        self.nombre1 = nombre1

    def presentarse (self):
        print(f'Yo me llamo {self.nombre1}')
