# %%
def calificaciones():
    nombre = input('ingrese el nombre del alumno')
    calificacion = input('ingrese la califcacion')
    print(f'el alumno {nombre} obtuvo la calificacion de nota {calificacion}')

calificaciones()
# Out:
# el alumno jose obtuvo la calificacion de nota cinco

# %%
def recibir(palabra, numero):
    if len(palabra) == numero:
        return True
    else:
        return False

resultado = recibir('manzana', 4)
print(resultado)
# Out:
# False

# %%
#no terminado
def lista():
    palabra_usuario = input('ingrese la palabra')   
    print(f'su palabra ingresada es {palabra_usuario}')

lista()
# Out:
# su palabra ingresada es cielo

# %%
# no funciona (terminar luego)
lista = ['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']
i = 0
def desglozar_lista(lista):
    for in range (len(lista)):
        print(lista(i))

desglozar_lista (lista)
