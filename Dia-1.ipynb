# %%
Edad = 19
Nombre = 'Matias'
Ciudad = 'Fernando de la Mora' 

print(Edad, Nombre, Ciudad)
# Out:
# 19 Matias Fernando de la Mora

# %%
print('hola mundo')
# Out:
# hola mundo

# %%
#Suma
Cantidad_de_manzanas = 10
Cabtidad_de_naranjas = 7

Cantidad_de_frutas = Cantidad_de_manzanas + Cabtidad_de_naranjas

print(Cantidad_de_frutas)

#Resta 
Frutas_vendidas = 15
Frutas_restantes = Cantidad_de_frutas - Frutas_vendidas 

print(Frutas_restantes)
# Out:
# 17
# 2

# %%
# Separacion de Datos
Nombre = 'Alan'
Apellido = 'Vera'

print('Hola, me llamo', Nombre,Apellido)

# Concatenacion 
print(f'hola mi nombre es {Nombre} {Apellido} ''mucho gusto')
# Out:
# Hola, me llamo Alan Vera
# hola mi nombre es Alan Vera mucho gusto

# %%
Caramelos = int(input('ingrese cantidad de caramelos'))
Niños = int(input('ingrese cantidad de niños'))
caramelo_recibidos = Caramelos // Niños
resto_de_caramelos = Caramelos % Niños

print(caramelo_recibidos)
print(resto_de_caramelos)
# Out:
# 0
# 15

# %%
def calificaciones():
    nombre = input('ingrese el nombre del alumno')
    calificacion = input('ingrese la califcacion')
    print(f'el alumno {nombre} obtuvo la calificacion de nota {calificacion}')


calificaciones()
calificaciones()
calificaciones()
# Out:
# el alumno jose obtuvo la calificacion de nota cinco
# el alumno juan obtuvo la calificacion de nota cuatro
# el alumno ana obtuvo la calificacion de nota cinco

# %%
Tamaño_helado = input('ingrese el tamaño del pedido')
Sabores_helado = input('ingrese el sabor del pedido')
Cobertura_helado = input('ingrese la cobertura que desea')

def preparar_pedido(tamaño, sabor, cobertura):
    print(f'preparando el pedido {tamaño} con sabor a {sabor} y cobertura de {cobertura}')
    print('pedido listo para retirar, que lo disfrute 🍦 :)') 

preparar_pedido(Tamaño_helado,Sabores_helado,Cobertura_helado)
# Out:
# preparando el pedido cucurucho con sabor a oreo y cobertura de chocolate
# pedido listo para retirar, que lo disfrute 🍦 :)

# %%
impuesto = 10 

def
